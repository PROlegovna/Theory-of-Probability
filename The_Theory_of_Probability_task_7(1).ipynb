# %%
# __Задача 1__
# Дана матрица объект-признак
# X = [[ 1.22401313,  2.30868478,  3.03636353,  2.69287214],
     # [-0.18757272,  1.30337355,  5.12093014,  3.46363202],
     # [-0.81094525,  1.82463398,  5.79686488,  1.86159445],
     # [ 0.75129018,  2.67392052,  3.65529809,  1.66746094],
     # [ 0.00972362,  1.97367255,  2.50594319,  1.69755173],
     # [-0.62972637,  0.77750764,  2.84124027,  4.54410559],
     # [ 2.29536229,  1.81206697,  1.95026215,  1.51874636],
     # [ 0.0920418 ,  2.26971361,  7.47708735,  2.61081203],
     # [ 2.39252799,  3.17563985,  3.61420599,  5.10773362],
     # [ 0.54983815,  2.87988651,  1.65752765,  1.59635987]]
# и значения целевой переменной
# y = [ 9.26193358,  9.700363  ,  8.67214805,  8.74796974,  6.18689108,
      # 7.53312713,  7.57643777, 12.44965478, 14.29010746,  6.68361218]
# Подберите два признака (из четырёх) так, чтобы уровень линейной зависимости целевой переменной от значений этих признаков был максимальным. Другими словами, модель линейной регрессии на этих признаках должна давать наилучший результат. В качестве ответа запишите значение коэффициента детерминации для модели на этих признаках.
# __Ответ__: 0.76342462
# __Задача 2__
# Является ли значимым уравнение регрессии, полученное в предыдущей задаче? В качестве ответа запишите 1, если является, и 0 иначе.
# __Ответ__: 1
# __Задача 3__
# Для проведения A/B-тестирования сайта интернет-магазина были получены следующие данные: страница `A` была посещена 2509 раз, из них 77 закончились совершением покупки, страница `B` была посещена 1465 раз, 60 из них закончились совершением покупки. Является ли значимым отличие конверсии на страницах `A` и `B`? В качестве ответа запишите 1, если является, и 0 иначе.
# _Подсказка_. Реализуйте двухвыборочный t-тест. В качестве выборок здесь можно взять наборы меток совершения покупки (0 или 1) каждым посетителем.
# __Ответ__: 0

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats

# %%
# __Задача 1__
# Дана матрица объект-признак
# X = [[ 1.22401313,  2.30868478,  3.03636353,  2.69287214],
     # [-0.18757272,  1.30337355,  5.12093014,  3.46363202],
     # [-0.81094525,  1.82463398,  5.79686488,  1.86159445],
     # [ 0.75129018,  2.67392052,  3.65529809,  1.66746094],
     # [ 0.00972362,  1.97367255,  2.50594319,  1.69755173],
     # [-0.62972637,  0.77750764,  2.84124027,  4.54410559],
     # [ 2.29536229,  1.81206697,  1.95026215,  1.51874636],
     # [ 0.0920418 ,  2.26971361,  7.47708735,  2.61081203],
     # [ 2.39252799,  3.17563985,  3.61420599,  5.10773362],
     # [ 0.54983815,  2.87988651,  1.65752765,  1.59635987]]
# и значения целевой переменной
# y = [ 9.26193358,  9.700363  ,  8.67214805,  8.74796974,  6.18689108,
      # 7.53312713,  7.57643777, 12.44965478, 14.29010746,  6.68361218]
# Подберите два признака (из четырёх) так, чтобы уровень линейной зависимости целевой переменной от значений этих признаков был максимальным. Другими словами, модель линейной регрессии на этих признаках должна давать наилучший результат. В качестве ответа запишите значение коэффициента детерминации для модели на этих признаках.
# __Ответ__: 0.76342462

# __Задача 2__
# Является ли значимым уравнение регрессии, полученное в предыдущей задаче? В качестве ответа запишите 1, если является, и 0 иначе.
# __Ответ__: 1

# %%
x1 = np.array([ 1.22401313, 2.30868478, 3.03636353, 2.69287214])
y1 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x2 = np.array([-0.18757272, 1.30337355, 5.12093014, 3.46363202])
y2 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x3 = np.array([-0.81094525, 1.82463398, 5.79686488, 1.86159445])
y3 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x4 = np.array([ 0.75129018, 2.67392052, 3.65529809, 1.66746094])
y4 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x5 = np.array([ 0.00972362, 1.97367255, 2.50594319, 1.69755173])
y5 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x6 = np.array([-0.62972637, 0.77750764, 2.84124027, 4.54410559])
y6 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x7 = np.array([ 2.29536229, 1.81206697, 1.95026215, 1.51874636])
y7 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x8 = np.array([ 0.0920418 , 2.26971361, 7.47708735, 2.61081203])
y8 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x9 = np.array([ 2.39252799, 3.17563985, 3.61420599, 5.10773362])
y9 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])
x10 = np.array([ 0.54983815, 2.87988651, 1.65752765, 1.59635987])
y10 = np.array([ 9.26193358, 9.700363 , 8.67214805, 8.74796974])

# %%
print(f"среднее X:{x1.mean()}, среднее Y:{y1.mean()}, дисперсия X:{x1.var()}, дисперсия Y:{y1.var()}")
print(f"среднее X:{x2.mean()}, среднее Y:{y2.mean()}, дисперсия X:{x2.var()}, дисперсия Y:{y2.var()}")
print(f"среднее X:{x3.mean()}, среднее Y:{y3.mean()}, дисперсия X:{x3.var()}, дисперсия Y:{y3.var()}")
print(f"среднее X:{x4.mean()}, среднее Y:{y4.mean()}, дисперсия X:{x4.var()}, дисперсия Y:{y4.var()}")
print(f"среднее X:{x5.mean()}, среднее Y:{y5.mean()}, дисперсия X:{x5.var()}, дисперсия Y:{y5.var()}")
print(f"среднее X:{x6.mean()}, среднее Y:{y6.mean()}, дисперсия X:{x6.var()}, дисперсия Y:{y6.var()}")
print(f"среднее X:{x7.mean()}, среднее Y:{y7.mean()}, дисперсия X:{x7.var()}, дисперсия Y:{y7.var()}")
print(f"среднее X:{x8.mean()}, среднее Y:{y8.mean()}, дисперсия X:{x8.var()}, дисперсия Y:{y8.var()}")
print(f"среднее X:{x9.mean()}, среднее Y:{y9.mean()}, дисперсия X:{x9.var()}, дисперсия Y:{y9.var()}")
print(f"среднее X:{x10.mean()}, среднее Y:{y10.mean()}, дисперсия X:{x10.var()}, дисперсия Y:{y10.var()}")
# Out:
# среднее X:2.315483395, среднее Y:9.0956035925, дисперсия X:0.4633609986088455, дисперсия Y:0.1733908743948653
# среднее X:2.4250907475, среднее Y:9.0956035925, дисперсия X:4.107594467604265, дисперсия Y:0.1733908743948653
# среднее X:2.168037015, среднее Y:9.0956035925, дисперсия X:5.563639924768995, дисперсия Y:0.1733908743948653
# среднее X:2.1869924325, среднее Y:9.0956035925, дисперсия X:1.1810435989439414, дисперсия Y:0.1733908743948653
# среднее X:1.5467227725, среднее Y:9.0956035925, дисперсия X:0.8718764227656074, дисперсия Y:0.1733908743948653
# среднее X:1.8832817825000001, среднее Y:9.0956035925, дисперсия X:3.88390355677129, дисперсия Y:0.1733908743948653
# среднее X:1.8941094425, среднее Y:9.0956035925, дисперсия X:0.07794634629606345, дисперсия Y:0.1733908743948653
# среднее X:3.1124136975, среднее Y:9.0956035925, дисперсия X:7.2836925405866815, дисперсия Y:0.1733908743948653
# ...

# %%
print(f"Коэф-т корреляции:{np.corrcoef(x1, y1)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x2, y2)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x3, y3)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x4, y4)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x5, y5)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x6, y6)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x7, y7)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x8, y8)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x9, y9)[0,1]}")
print(f"Коэф-т корреляции:{np.corrcoef(x10, y10)[0,1]}")
# Out:
# Коэф-т корреляции:-0.5486988161603074
# Коэф-т корреляции:-0.7748067661946957
# Коэф-т корреляции:-0.5429962430103576
# Коэф-т корреляции:-0.21295968083046407
# Коэф-т корреляции:-0.29324367420780334
# Коэф-т корреляции:-0.7364346552833899
# Коэф-т корреляции:0.2663011182620712
# Коэф-т корреляции:-0.5974998700344799
# Коэф-т корреляции:-0.5998533723682781
# Коэф-т корреляции:0.419232615129641

# %%
#найдем коэф-ты линейной регрессии
b1_1 = np.cov(x1, y1, ddof=0)[0, 1] / np.var(x1, ddof=0)
b0_1 = y1.mean() - b1_1 * x1.mean()

b1_2 = np.cov(x2, y2, ddof=0)[0, 1] / np.var(x2, ddof=0)
b0_2 = y2.mean() - b1_2 * x2.mean()

b1_3 = np.cov(x3, y3, ddof=0)[0, 1] / np.var(x3, ddof=0)
b0_3 = y3.mean() - b1_3 * x3.mean()

b1_4 = np.cov(x4, y4, ddof=0)[0, 1] / np.var(x4, ddof=0)
b0_4 = y4.mean() - b1_4 * x4.mean()

b1_5 = np.cov(x5, y5, ddof=0)[0, 1] / np.var(x5, ddof=0)
b0_5 = y5.mean() - b1_5 * x5.mean()

b1_6 = np.cov(x6, y6, ddof=0)[0, 1] / np.var(x6, ddof=0)
b0_6 = y6.mean() - b1_6 * x6.mean()

b1_7 = np.cov(x7, y7, ddof=0)[0, 1] / np.var(x7, ddof=0)
b0_7 = y7.mean() - b1_7 * x7.mean()

b1_8 = np.cov(x8, y8, ddof=0)[0, 1] / np.var(x8, ddof=0)
b0_8 = y8.mean() - b1_8 * x8.mean()

b1_9 = np.cov(x9, y9, ddof=0)[0, 1] / np.var(x9, ddof=0)
b0_9 = y9.mean() - b1_9 * x9.mean()

b1_10 = np.cov(x10, y10, ddof=0)[0, 1] / np.var(x10, ddof=0)
b0_10 = y10.mean() - b1_10 * x10.mean()

# %%
ox1 = x1
oy1 = b0_1 + b1_1 * ox1

plt.scatter(x1, y1)
plt.plot(ox1, oy1, color='red', alpha=0.5)

# %%
ox2 = x2
oy2 = b0_2 + b1_2 * ox2

plt.scatter(x2, y2)
plt.plot(ox2, oy2, color='red', alpha=0.5)

# %%
ox3 = x3
oy3 = b0_3 + b1_3 * ox3

plt.scatter(x3, y3)
plt.plot(ox3, oy3, color='red', alpha=0.5)

# %%
ox4 = x4
oy4 = b0_4 + b1_4 * ox4

plt.scatter(x4, y4)
plt.plot(ox4, oy4, color='red', alpha=0.5)

# %%
ox5 = x5
oy5 = b0_5 + b1_5 * ox5

plt.scatter(x5, y5)
plt.plot(ox5, oy5, color='red', alpha=0.5)

# %%
ox6 = x6
oy6 = b0_6 + b1_6 * ox6

plt.scatter(x6, y6)
plt.plot(ox6, oy6, color='red', alpha=0.5)

# %%
ox7 = x7
oy7 = b0_7 + b1_7 * ox7

plt.scatter(x7, y7)
plt.plot(ox7, oy7, color='red', alpha=0.5)

# %%
ox8 = x8
oy8 = b0_8 + b1_8 * ox4

plt.scatter(x8, y8)
plt.plot(ox8, oy8, color='red', alpha=0.5)

# %%
ox9 = x9
oy9 = b0_9 + b1_9 * ox9

plt.scatter(x9, y9)
plt.plot(ox9, oy9, color='red', alpha=0.5)

# %%
ox10 = x10
oy10 = b0_10 + b1_10 * ox10

plt.scatter(x10, y10)
plt.plot(ox10, oy10, color='red', alpha=0.5)

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10) = plt.subplots(ncols=10)
fig.set_size_inches(50,5)
ax1.scatter(x1, y1)
ax1.plot(ox1, oy1, color='red', alpha=0.5)
ax1.set_title("1 пара")

ax2.scatter(x2, y2)
ax2.plot(ox2, oy2, color='red', alpha=0.5)
ax2.set_title("2 пара")

ax3.scatter(x3, y3)
ax3.plot(ox3, oy3, color='red', alpha=0.5)
ax3.set_title("3 пара")

ax4.scatter(x4, y4)
ax4.plot(ox4, oy4, color='red', alpha=0.5)
ax4.set_title("4 пара")

ax5.scatter(x5, y5)
ax5.plot(ox5, oy5, color='red', alpha=0.5)
ax5.set_title("5 пара")

ax6.scatter(x6, y6)
ax6.plot(ox6, oy6, color='red', alpha=0.5)
ax6.set_title("6 пара")

ax7.scatter(x7, y7)
ax7.plot(ox7, oy7, color='red', alpha=0.5)
ax7.set_title("7 пара")

ax8.scatter(x8, y8)
ax8.plot(ox8, oy8, color='red', alpha=0.5)
ax8.set_title("8 пара")

ax9.scatter(x9, y9)
ax9.plot(ox9, oy9, color='red', alpha=0.5)
ax9.set_title("9 пара")

ax10.scatter(x10, y10)
ax10.plot(ox10, oy10, color='red', alpha=0.5)
ax10.set_title("10 пара")
# Out:
# Text(0.5, 1.0, '10 пара')

# %%
# __Задача 3__
# Для проведения A/B-тестирования сайта интернет-магазина были получены следующие данные: 
# страница `A` была посещена 2509 раз, 
# из них 77 закончились совершением покупки, 
# страница `B` была посещена 1465 раз, 
# 60 из них закончились совершением покупки. 
# Является ли значимым отличие конверсии на страницах `A` и `B`? 
# В качестве ответа запишите 1, если является, и 0 иначе.
# _Подсказка_. Реализуйте двухвыборочный t-тест. В качестве выборок здесь можно взять наборы меток совершения покупки (0 или 1) каждым посетителем.
# __Ответ__: 0

# %%
import numpy as np

# %%
page_A = np.array([2509])
page_B = np.array([1465])

# %%
b1 = (np.mean(page_A / 77))
b1
# Out:
# 32.58441558441559

# %%
b0 = (np.mean(page_B / 60))
b0
# Out:
# 24.416666666666668

# %%
R1 = b1 / b0
R1
# Out:
# 1.3345153140374983

# %%
from scipy import stats

# %%
alpha = 0.77

t = stats.t.ppf(1 - alpha / 2, df=8)
t
# Out:
# 0.3024818765962574

# %%
alpha = 0.60

t = stats.t.ppf(1 - alpha / 2, df=8)
t
# Out:
# 0.545933763540471
